# %% [markdown]
# ## Dependencies

# %%
import torch

import torch.nn as nn
import torch.optim as optim

import torch.nn.functional as F
from torch.autograd import Variable

import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

import torchvision.models as models

import imp
import os
import sys
import math
import utils.training as train_utils; imp.reload(train_utils)
import utils.plot as plot_utils; imp.reload(plot_utils)
import time
from tqdm import tqdm

# %%
DATA_PATH='data/'
RESULTS_PATH='results/'
WEIGHTS_PATH='models/'

# %% [markdown]
# ## Layers

# %%
class Bottleneck(nn.Module):
    def __init__(self, nChannels, growthRate):
        super(Bottleneck, self).__init__()
        interChannels = 4*growthRate
        self.bn1 = nn.BatchNorm2d(nChannels)
        self.conv1 = nn.Conv2d(nChannels, interChannels, kernel_size=1,
                               bias=False)
        self.bn2 = nn.BatchNorm2d(interChannels)
        self.conv2 = nn.Conv2d(interChannels, growthRate, kernel_size=3,
                               padding=1, bias=False)

    def forward(self, x):
        out = self.conv1(F.relu(self.bn1(x)))
        out = self.conv2(F.relu(self.bn2(out)))
        out = torch.cat((x, out), 1)
        return out

class SingleLayer(nn.Module):
    def __init__(self, nChannels, growthRate):
        super(SingleLayer, self).__init__()
        self.bn1 = nn.BatchNorm2d(nChannels)
        self.conv1 = nn.Conv2d(nChannels, growthRate, kernel_size=3,
                               padding=1, bias=False)

    def forward(self, x):
        out = self.conv1(F.relu(self.bn1(x)))
        out = torch.cat((x, out), 1)
        return out

class Transition(nn.Module):
    def __init__(self, nChannels, nOutChannels):
        super(Transition, self).__init__()
        self.bn1 = nn.BatchNorm2d(nChannels)
        self.conv1 = nn.Conv2d(nChannels, nOutChannels, kernel_size=1,
                               bias=False)

    def forward(self, x):
        out = self.conv1(F.relu(self.bn1(x)))
        out = F.avg_pool2d(out, 2)
        return out

# %% [markdown]
# ## Model

# %%
class DenseNet(nn.Module):
    def __init__(self, growthRate, depth, reduction, nClasses, bottleneck):
        super(DenseNet, self).__init__()

        nDenseBlocks = (depth-4) // 3
        if bottleneck:
            nDenseBlocks //= 2

        nChannels = 2*growthRate
        self.conv1 = nn.Conv2d(3, nChannels, kernel_size=3, padding=1,
                               bias=False)
        self.dense1 = self._make_dense(nChannels, growthRate, nDenseBlocks, bottleneck)
        nChannels += nDenseBlocks*growthRate
        nOutChannels = int(math.floor(nChannels*reduction))
        self.trans1 = Transition(nChannels, nOutChannels)

        nChannels = nOutChannels
        self.dense2 = self._make_dense(nChannels, growthRate, nDenseBlocks, bottleneck)
        nChannels += nDenseBlocks*growthRate
        nOutChannels = int(math.floor(nChannels*reduction))
        self.trans2 = Transition(nChannels, nOutChannels)

        nChannels = nOutChannels
        self.dense3 = self._make_dense(nChannels, growthRate, nDenseBlocks, bottleneck)
        nChannels += nDenseBlocks*growthRate

        self.bn1 = nn.BatchNorm2d(nChannels)
        self.fc = nn.Linear(nChannels, nClasses)

        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                m.bias.data.zero_()

    def _make_dense(self, nChannels, growthRate, nDenseBlocks, bottleneck):
        layers = []
        for i in range(int(nDenseBlocks)):
            if bottleneck:
                layers.append(Bottleneck(nChannels, growthRate))
            else:
                layers.append(SingleLayer(nChannels, growthRate))
            nChannels += growthRate
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.conv1(x)
        out = self.trans1(self.dense1(out))
        out = self.trans2(self.dense2(out))
        out = self.dense3(out)
        out = torch.squeeze(F.avg_pool2d(F.relu(self.bn1(out)), 8))
        out = F.log_softmax(self.fc(out))
        return out

# %%
# Test
model = DenseNet(12,100,.4,10,False)
print(model)
# Out:
# DenseNet (
#   (conv1): Conv2d(3, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (dense1): Sequential (
#     (0): SingleLayer (
#       (bn1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(24, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (1): SingleLayer (
#       (bn1): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(36, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (2): SingleLayer (
#       (bn1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (3): SingleLayer (
#       (bn1): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(60, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (4): SingleLayer (
#       (bn1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(72, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (5): SingleLayer (
#       (bn1): BatchNorm2d(84, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(84, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (6): SingleLayer (
#       (bn1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(96, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (7): SingleLayer (
#       (bn1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(108, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (8): SingleLayer (
#       (bn1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(120, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (9): SingleLayer (
#       (bn1): BatchNorm2d(132, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(132, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (10): SingleLayer (
#       (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(144, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (11): SingleLayer (
#       (bn1): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(156, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (12): SingleLayer (
#       (bn1): BatchNorm2d(168, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(168, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (13): SingleLayer (
#       (bn1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(180, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (14): SingleLayer (
#       (bn1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(192, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (15): SingleLayer (
#       (bn1): BatchNorm2d(204, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(204, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (16): SingleLayer (
#       (bn1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(216, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (17): SingleLayer (
#       (bn1): BatchNorm2d(228, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(228, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (18): SingleLayer (
#       (bn1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(240, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (19): SingleLayer (
#       (bn1): BatchNorm2d(252, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(252, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (20): SingleLayer (
#       (bn1): BatchNorm2d(264, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(264, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (21): SingleLayer (
#       (bn1): BatchNorm2d(276, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(276, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (22): SingleLayer (
#       (bn1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(288, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (23): SingleLayer (
#       (bn1): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(300, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (24): SingleLayer (
#       (bn1): BatchNorm2d(312, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(312, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (25): SingleLayer (
#       (bn1): BatchNorm2d(324, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(324, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (26): SingleLayer (
#       (bn1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(336, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (27): SingleLayer (
#       (bn1): BatchNorm2d(348, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(348, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (28): SingleLayer (
#       (bn1): BatchNorm2d(360, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(360, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (29): SingleLayer (
#       (bn1): BatchNorm2d(372, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(372, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (30): SingleLayer (
#       (bn1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(384, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (31): SingleLayer (
#       (bn1): BatchNorm2d(396, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(396, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#   )
#   (trans1): Transition (
#     (bn1): BatchNorm2d(408, eps=1e-05, momentum=0.1, affine=True)
#     (conv1): Conv2d(408, 163, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (dense2): Sequential (
#     (0): SingleLayer (
#       (bn1): BatchNorm2d(163, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(163, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (1): SingleLayer (
#       (bn1): BatchNorm2d(175, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(175, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (2): SingleLayer (
#       (bn1): BatchNorm2d(187, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(187, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (3): SingleLayer (
#       (bn1): BatchNorm2d(199, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(199, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (4): SingleLayer (
#       (bn1): BatchNorm2d(211, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(211, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (5): SingleLayer (
#       (bn1): BatchNorm2d(223, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(223, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (6): SingleLayer (
#       (bn1): BatchNorm2d(235, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(235, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (7): SingleLayer (
#       (bn1): BatchNorm2d(247, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(247, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (8): SingleLayer (
#       (bn1): BatchNorm2d(259, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(259, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (9): SingleLayer (
#       (bn1): BatchNorm2d(271, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(271, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (10): SingleLayer (
#       (bn1): BatchNorm2d(283, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(283, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (11): SingleLayer (
#       (bn1): BatchNorm2d(295, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(295, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (12): SingleLayer (
#       (bn1): BatchNorm2d(307, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(307, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (13): SingleLayer (
#       (bn1): BatchNorm2d(319, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(319, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (14): SingleLayer (
#       (bn1): BatchNorm2d(331, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(331, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (15): SingleLayer (
#       (bn1): BatchNorm2d(343, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(343, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (16): SingleLayer (
#       (bn1): BatchNorm2d(355, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(355, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (17): SingleLayer (
#       (bn1): BatchNorm2d(367, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(367, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (18): SingleLayer (
#       (bn1): BatchNorm2d(379, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(379, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (19): SingleLayer (
#       (bn1): BatchNorm2d(391, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(391, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (20): SingleLayer (
#       (bn1): BatchNorm2d(403, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(403, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (21): SingleLayer (
#       (bn1): BatchNorm2d(415, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(415, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (22): SingleLayer (
#       (bn1): BatchNorm2d(427, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(427, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (23): SingleLayer (
#       (bn1): BatchNorm2d(439, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(439, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (24): SingleLayer (
#       (bn1): BatchNorm2d(451, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(451, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (25): SingleLayer (
#       (bn1): BatchNorm2d(463, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(463, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (26): SingleLayer (
#       (bn1): BatchNorm2d(475, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(475, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (27): SingleLayer (
#       (bn1): BatchNorm2d(487, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(487, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (28): SingleLayer (
#       (bn1): BatchNorm2d(499, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(499, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (29): SingleLayer (
#       (bn1): BatchNorm2d(511, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(511, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (30): SingleLayer (
#       (bn1): BatchNorm2d(523, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(523, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (31): SingleLayer (
#       (bn1): BatchNorm2d(535, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(535, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#   )
#   (trans2): Transition (
#     (bn1): BatchNorm2d(547, eps=1e-05, momentum=0.1, affine=True)
#     (conv1): Conv2d(547, 218, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (dense3): Sequential (
#     (0): SingleLayer (
#       (bn1): BatchNorm2d(218, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(218, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (1): SingleLayer (
#       (bn1): BatchNorm2d(230, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(230, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (2): SingleLayer (
#       (bn1): BatchNorm2d(242, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(242, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (3): SingleLayer (
#       (bn1): BatchNorm2d(254, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(254, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (4): SingleLayer (
#       (bn1): BatchNorm2d(266, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(266, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (5): SingleLayer (
#       (bn1): BatchNorm2d(278, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(278, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (6): SingleLayer (
#       (bn1): BatchNorm2d(290, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(290, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (7): SingleLayer (
#       (bn1): BatchNorm2d(302, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(302, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (8): SingleLayer (
#       (bn1): BatchNorm2d(314, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(314, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (9): SingleLayer (
#       (bn1): BatchNorm2d(326, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(326, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (10): SingleLayer (
#       (bn1): BatchNorm2d(338, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(338, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (11): SingleLayer (
#       (bn1): BatchNorm2d(350, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(350, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (12): SingleLayer (
#       (bn1): BatchNorm2d(362, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(362, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (13): SingleLayer (
#       (bn1): BatchNorm2d(374, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(374, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (14): SingleLayer (
#       (bn1): BatchNorm2d(386, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(386, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (15): SingleLayer (
#       (bn1): BatchNorm2d(398, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(398, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (16): SingleLayer (
#       (bn1): BatchNorm2d(410, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(410, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (17): SingleLayer (
#       (bn1): BatchNorm2d(422, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(422, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (18): SingleLayer (
#       (bn1): BatchNorm2d(434, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(434, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (19): SingleLayer (
#       (bn1): BatchNorm2d(446, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(446, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (20): SingleLayer (
#       (bn1): BatchNorm2d(458, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(458, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (21): SingleLayer (
#       (bn1): BatchNorm2d(470, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(470, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (22): SingleLayer (
#       (bn1): BatchNorm2d(482, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(482, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (23): SingleLayer (
#       (bn1): BatchNorm2d(494, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(494, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (24): SingleLayer (
#       (bn1): BatchNorm2d(506, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(506, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (25): SingleLayer (
#       (bn1): BatchNorm2d(518, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(518, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (26): SingleLayer (
#       (bn1): BatchNorm2d(530, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(530, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (27): SingleLayer (
#       (bn1): BatchNorm2d(542, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(542, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (28): SingleLayer (
#       (bn1): BatchNorm2d(554, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(554, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (29): SingleLayer (
#       (bn1): BatchNorm2d(566, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(566, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (30): SingleLayer (
#       (bn1): BatchNorm2d(578, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(578, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (31): SingleLayer (
#       (bn1): BatchNorm2d(590, eps=1e-05, momentum=0.1, affine=True)
#       (conv1): Conv2d(590, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#   )
#   (bn1): BatchNorm2d(602, eps=1e-05, momentum=0.1, affine=True)
#   (fc): Linear (602 -> 10)
# )

# %% [markdown]
# ## Data

# %%
BATCH_SIZE=64
CIFAR10_PATH=DATA_PATH+'cifar10/'

# %%
torch.cuda.manual_seed(1)

normMean = [0.49139968, 0.48215827, 0.44653124]
normStd = [0.24703233, 0.24348505, 0.26158768]
normTransform = transforms.Normalize(normMean, normStd)

trainTransform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    normTransform
])
testTransform = transforms.Compose([
    transforms.ToTensor(),
    normTransform
])

kwargs = {'num_workers': 1, 'pin_memory': True}
trainLoader = DataLoader(
    dset.CIFAR10(root=CIFAR10_PATH, train=True, download=True,
                 transform=trainTransform),
    batch_size=BATCH_SIZE, shuffle=True, **kwargs)
testLoader = DataLoader(
    dset.CIFAR10(root=CIFAR10_PATH, train=False, download=True,
                 transform=testTransform),
    batch_size=BATCH_SIZE, shuffle=False, **kwargs)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# ## Train

# %%
existing_weights_fpath=None
nEpochs=1

net = DenseNet(growthRate=12, depth=40, reduction=1.0, 
                   bottleneck=False, nClasses=10)
net = net.cuda()

optimizer = optim.SGD(net.parameters(), lr=1e-1,
                momentum=0.9, weight_decay=1e-4)

print('  + Number of params: {}'.format(
    sum([p.data.nelement() for p in net.parameters()])))

if existing_weights_fpath:
    startEpoch = train_utils.load_weights(net, existing_weights_fpath)
    endEpoch = startEpoch + nEpochs
    print ('Resume training at epoch: {}'.format(startEpoch))
    if os.path.exists(RESULTS_PATH+'train.csv'): #assume test.csv exists
        append_write = 'a' # append if already exists
    else:
        append_write = 'w' # make a new file if not
    trainF = open(os.path.join(RESULTS_PATH, 'train.csv'), append_write)
    testF = open(os.path.join(RESULTS_PATH, 'test.csv'), append_write)
else:
    print ("Training new model from scratch")
    startEpoch = 1
    endEpoch = nEpochs
    trainF = open(os.path.join(RESULTS_PATH, 'train.csv'), 'w')
    testF = open(os.path.join(RESULTS_PATH, 'test.csv'), 'w')


for epoch in tqdm(range(startEpoch, endEpoch+1)):
    since = time.time()
    train_utils.adjust_opt("sgd", optimizer, epoch)
    train_utils.train(epoch, net, trainLoader, optimizer, trainF)
    train_utils.test(epoch, net, testLoader, optimizer, testF)
    time_elapsed = time.time() - since  
    print('Time {:.0f}m {:.0f}s\n'.format(
        time_elapsed // 60, time_elapsed % 60))
    if epoch != 1:
        os.system('./utils/plot.py {} &'.format(RESULTS_PATH))

trainF.close()
testF.close()
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   + Number of params: 1059298
# Training new model from scratch
# Epoch 1: Train - Loss: 1.370707	Error: 43.750000
# 100%|██████████| 1/1 [01:12<00:00, 72.19s/it]
# Test - Loss: 1.3404, Error: 4590/10000 (46%)
# Time 1m 12s
